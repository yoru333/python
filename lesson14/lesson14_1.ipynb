# %%
import numpy as np
 #陣列的運算
odd = [1, 3, 5, 7, 9]
even = [2, 4, 6, 8, 10]
odd_array = np.array(odd) #使其可以進行陣列運算 兩個都得是.array
even_array = np.array(even)
print(odd_array + even_array)
# Out:
# [ 3  7 11 15 19]

# %%
import numpy as np
o = np.arange(1,5.2,0.6) #起始 停止 間隔 
np.linspace(0,1,50) #起始 結束(包含) 有幾個數字
# Out:
# 8

# %%
import math
import matplotlib.pyplot as plt

t = np.arange(0, 2.5, 0.1)
y1 = np.sin(t * math.pi)
y2 = np.sin(t * math.pi + math.pi/2)
y3 = np.sin(t * math.pi - math.pi/2)

plt.plot(t, y1,marker="*", color='blue',linestyle='')
plt.plot(t, y2,marker="^", color='green',linestyle='')
plt.plot(t, y3,marker="s", color='yellow',linestyle='')
# plt.savefig('a.png')
plt.show()
plt.close()
