# %%
import numpy as np
import pandas as pd
#建立50位學生5個分數,每個分數的值是50~100之間的隨機整數
scores = np.random.randint(50,101,size=(50, 5))
score_pd = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=[f'學生{index}' for index in range(1,51)])
type(score_pd.index)
score_pd.columns.name = '科目'
score_pd.index.name = '學號'
sum_series = np.sum(score_pd, axis=1)
mean_series = score_pd.mean(axis=1)
score_pd['總分'] = sum_series
score_pd['平均'] = mean_series
score_pd.to_excel("三年五班.xlsx", index=True)

# %%
import os
import pandas as pd
import numpy as np
#建立50位學生5個分數,每個分數的值是50~100之間的隨機整數
scores = np.random.randint(50,101,size=(50, 5))
score_pd = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=[f'學生{index}' for index in range(1,51)])
type(score_pd.index)
score_pd.columns.name = '科目'
score_pd.index.name = '學號'
score_pd.to_excel('三年五班.xlsx',index=True)

def rank(filepath:str):
    df = pd.read_excel(filepath,index_col='學號')
    display(df)

script_path = os.path.realpath(__name__)
script_root = os.path.dirname(script_path) # 從完整路徑中取得目錄（資料夾）路徑
excel_folder = os.path.join(script_root,"excel") # 將程式所在的目錄與 "excel" 子資料夾結合，組成完整路徑
for excel_name in os.listdir(excel_folder):
    excel_path = os.path.join(excel_folder,excel_name)
    rank(excel_path)
# Out:
#       國文   英文   數學   地理   歷史   總分    平均
# 學號
# 學生1   91   64   63   95   78  391  78.2
# 學生2   62   95   73   53   84  367  73.4
# 學生3   70   80   98   80   74  402  80.4
# 學生4   96   64   63   76   90  389  77.8
# 學生5   90   96   83   68   83  420  84.0
# 學生6   64   61  100  100   97  422  84.4
# 學生7   83   57   90   80   74  384  76.8
# 學生8   71   91   96   72   54  384  76.8
# 學生9   67   96   98   62   83  406  81.2
# 學生10  83   90   76   74   94  417  83.4
# 學生11  80   68   80   50   76  354  70.8
# 學生12  75   77   78   57   71  358  71.6
# 學生13  77  100   88   81   84  430  86.0
# 學生14  98   93   76   92   78  437  87.4
# 學生15  83   62   88   97   79  409  81.8
# 學生16  59   63   58   76   82  338  67.6
# 學生17  76   67   62   91   61  357  71.4
# 學生18  91   65   98   66   71  391  78.2
# 學生19  76   96   76   51   99  398  79.6
# 學生20  90   63   78   56  100  387  77.4
# 學生21  87   68   93   64   70  382  76.4
# 學生22  79   82   80   82   87  410  82.0
# 學生23  57   82   80   65   76  360  72.0
# 學生24  70   80   65   98   85  398  79.6
# 學生25  64   94   52   68   81  359  71.8
# 學生26  52   73   78   82   60  345  69.0
# 學生27  68   58   70   50   59  305  61.0
# 學生28  63   88   66   94   80  391  78.2
# 學生29  53   78   85  100   52  368  73.6
# 學生30  61   69   87   83   64  364  72.8
# 學生31  53  100   55   91   98  397  79.4
# 學生32  81   70   69   57   80  357  71.4
# 學生33  87   64   83   71   72  377  75.4
# 學生34  61   98   76   54   54  343  68.6
# 學生35  57   92   60   77   59  345  69.0
# 學生36  59   70   50   54   75  308  61.6
# 學生37  86   71   55   71   54  337  67.4
# 學生38  83   64   97   85   76  405  81.0
# 學生39  63   73   92   78   73  379  75.8
# 學生40  73   55   73   69   94  364  72.8
# 學生41  93   58   53   72   74  350  70.0
# 學生42  65   94   67   97   95  418  83.6
# 學生43  79   75   75   85   96  410  82.0
# 學生44  68   87   60   66   84  365  73.0
# 學生45  69   59   99   50   69  346  69.2
# 學生46  60   90   78   82   50  360  72.0
# 學生47  92   61   99   68   67  387  77.4
# 學生48  97   67   82   56   93  395  79.0
# 學生49  87   54   51   95   80  367  73.4
# 學生50  54   91   77   73   83  378  75.6
