# %%
import pandas as pd

df = pd.read_csv("各鄉鎮市區人口密度.csv")
df1 = df.rename(columns={"statistic_yyy":"統計年",
                   "site_id":"區域別",
                   "people_total":"年底人口數",
                   "area":"土地面積",
                   "population_density":"人口密度"
                   })
df2 = df1.drop(["統計年"], axis=1) #刪除欄位
df3 = df2.dropna(axis=0) #刪除空值
df4 = df3.drop(index=0) #刪除索引

def string_to_int(value:str): #轉資料型態工具
    try:
        v = int(value)
        return v
    except Exception:
        return 0
    
df4["年底人口數"] = df4["年底人口數"].map(string_to_int) #df["欄位"].map(函數)
df4["人口密度"] = df4["人口密度"].apply(string_to_int) #df["欄位"].apply(函數, axis=1 or 0) 同map功能 但可支援多欄位
#表函數是作用在 每一列（row） → 所以你能夠同時存取「多個欄位」。
df4['土地面積'] = df4['土地面積'].astype(float)

def split_words(v:str):
    if len(v) == 6:
        return v[:3] #抓出前三個字
    else:
        return v

df4["縣市"] = df4['區域別'].map(split_words)

def split_area(v:str):
    if len(v) == 6:
        return v[-3:]  #抓出倒數3個字
    else:
        return v
df4['區域別'] = df4['區域別'].map(split_area)
df5 = df4.reindex(columns=["區域別","縣市","年底人口數","土地面積","人口密度"]) #重新安排 df4 的欄位順序或欄位內容
df6 = df5.set_index('區域別') #「區域別」現在變成左邊的索引（row index），而不是欄位之一了。
# df6.to_excel('各鄉鎮市區人口密度.xlsx',index=True)
df6
# Out:
#         縣市   年底人口數     土地面積   人口密度
# 區域別
# 板橋區    新北市  551480  23.1373  23835
# 三重區    新北市  387484  16.3170  23747
# 中和區    新北市  413590  20.1440  20532
# 永和區    新北市  222585   5.7138  38956
# 新莊區    新北市  416524  19.7383  21102
# ...    ...     ...      ...    ...
# 北竿鄉    連江縣    2360   9.9000    238
# 莒光鄉    連江縣    1624   4.7000    346
# 東引鄉    連江縣    1352   3.8000    356
# 東沙群島  東沙群島       0   2.3800      0
# 南沙群島  南沙群島       0   0.5045      0
#
# [370 rows x 4 columns]
