# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes1 = figure.add_subplot(3, 1, 1) #3列 1欄 第一個
axes1 = figure.add_subplot(3, 1, 2)
axes1 = figure.add_subplot(3, 1, 3)
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.subplots(3,1)
plt.show()

# %%
import matplotlib.pyplot as plt

figure, axes = plt.subplots(3, 1)
plt.show()
